# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import os
import netCDF4 as nc
import datetime
pd.options.display.max_rows=6

# %%
SO2=pd.read_csv('./dataset/question2/SO2/v432_SO2_1970_2012.csv',encoding='utf-8',engine='python',skiprows=[i for i in range(7)])

# %%
longwave=nc.Dataset('./dataset/question2/Longwave Radiation/olr.mon.mean.nc')

# %%
longwave.variables.keys()
# Out:
# dict_keys(['lon', 'olr', 'time', 'lat'])

# %%
olr=longwave['olr']

# %%
from netCDF4 import num2date, date2num
llat=longwave['lat'][:].squeeze()
llon=longwave['lon'][:].squeeze()
tim=longwave.variables['time']
len(tim)
# Out:
# 408

# %%
time=[]
for t in range(len(tim)):
    time.append(int(str(num2date(tim[t],units=tim.units))[0:4]))
years=list(set(time))
print(years)
# Out:
# [1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012]

# %%
olr_m_g_mean=[]
for t in range(408):
    olr_m_g_mean.append(olr[t].mean())
olr_m_g_mean=pd.DataFrame(olr_m_g_mean)

# %%
temp=[]
for i in range(34):
    temp.append(olr_m_g_mean[i:i+12].mean())
olr_y_g_mean=pd.DataFrame(temp,index=years)
olr_y_g_mean
# Out:
#                0
# 1979  221.895243
# 1980  221.925456
# 1981  222.101196
# ...          ...
# 2010  222.305969
# 2011  222.162374
# 2012  222.088684
#
# [34 rows x 1 columns]

# %%
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(1,1,1)
ax.set_title('Global Year Mean OLR',fontsize=20)
ax.plot(olr_y_g_mean,label='OLR_year_mean')
plt.xticks(fontsize=15)
plt.yticks(fontsize=20)
ax.legend(fontsize=20)

# %%
sst=nc.Dataset('./dataset/question2/SST/sst.mnmean.nc')
sst.variables.keys()
# Out:
# dict_keys(['lat', 'lon', 'time_bnds', 'time', 'sst'])

# %% [markdown]
# ###  CO2

# %%
CO2=pd.read_csv('./dataset/question2/CO2/v432_CO2_org_short-cycle_C_1970_2012.csv',encoding='utf-8',engine='python',skiprows=[i for i in range(7)])

# %%
pd.options.display.max_rows=10
co2=pd.DataFrame(CO2)
co2.drop(co2.columns[0:6], axis=1, inplace=True)
co2
# Out:
#           1970       1971       1972      1973      1974      1975      1976  \
# 0      783.000    798.000    796.000    825.00    813.00    602.00    625.00
# 1    22700.000  23100.000  23100.000  23900.00  23500.00  17400.00  17900.00
# 2          NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 3     7600.000   7600.000   7600.000   7600.00   7600.00   7600.00   7600.00
# 4     2300.000   3210.000   3020.000   3200.00   2770.00   3240.00   3960.00
# ..         ...        ...        ...       ...       ...       ...       ...
# 981     11.400     11.200     11.000     10.90     11.30     11.10     11.30
# 982        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 983        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 984      0.833      0.899      0.984      1.03      1.12      1.25      1.39
# 985        NaN        NaN        NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
co2_y_g_mean=pd.DataFrame(co2.mean())[9:]
co2_y_g_mean
# Out:
#                 0
# 1979  5228.919312
# 1980  5358.305639
# 1981  5276.944511
# 1982  5365.938797
# 1983  5476.605064
# ...           ...
# 2008  6752.753849
# 2009  6722.120120
# 2010  6989.937205
# 2011  7158.411046
# 2012  7193.681428
#
# [34 rows x 1 columns]

# %%
fig=plt.figure(figsize=(20, 10))
ax=fig.add_subplot(1,1,1)
ax.set_title('Global Year Mean CO2',fontsize=20)
#ticks=ax.set_xticks([i for i in range(12)])
#labels = ax.set_xticklabels([y for y in range(1970,2012,5)])
ax.plot(co2_y_g_mean,label='CO2_global_year_mean')
plt.xticks(fontsize=10)
plt.yticks(fontsize=20)
ax.legend(fontsize=20)

# %%
sst=nc.Dataset('./dataset/question2/SST/sst.mnmean.nc')

# %%
sst.variables.keys()
# Out:
# dict_keys(['lat', 'lon', 'time_bnds', 'time', 'sst'])

# %%
sstdata=sst['sst'][:]

# %%
from netCDF4 import num2date, date2num
slat=sst['lat'][:].squeeze()
slon=sst['lon'][:].squeeze()
stime=sst.variables['time']
len(stime)
# Out:
# 1985

# %%
time=[]
for t in range(len(stime)):
    time.append(int(str(num2date(stime[t],units=stime.units))[0:4]))
syears=list(set(time))

# %%
sst_m_g_mean=[]
for t in range(1985):
    sst_m_g_mean.append(sstdata[t].mean())
print(len(sst_m_g_mean))
sst_m_g_mean=pd.DataFrame(sst_m_g_mean)
# Out:
# 1985

# %%
temp=[]
for i in range(166):
    temp.append(sst_m_g_mean[i:i+12].mean())
sst_y_g_mean=pd.DataFrame(temp,index=syears)
sst_y_g_mean
# Out:
#               0
# 1854  13.515060
# 1855  13.518019
# 1856  13.523583
# 1857  13.522145
# 1858  13.525203
# ...         ...
# 2015  13.480119
# 2016  13.495453
# 2017  13.504898
# 2018  13.502354
# 2019  13.493126
#
# [166 rows x 1 columns]

# %%
fig=plt.figure(figsize=(20, 10))
ax=fig.add_subplot(1,1,1)
ax.set_title('Global Year Mean SST',fontsize=20)
#ticks=ax.set_xticks([i for i in range(12)])
#labels = ax.set_xticklabels([y for y in range(1970,2012,5)])
ax.plot(sst_y_g_mean,label='global year mean sst')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.legend(fontsize=20)

# %%
tmax=nc.Dataset('./dataset/question2/CPC/tmax.day.ltm.nc')
tmax
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     Conventions: CF-1.0
#     Source: http://climate.geog.udel.edu/~climate/html_pages/Global2_Ts_2009/README.global_p_ts_2009.html
#     References: CPC GLOBAL PRCP
#     version: V1.0
#     history: Created 2016/09/15 by doDayLTM2
#     title: CPC GLOBAL TEMP V1.0
#     dataset_title: CPC GLOBAL TEMP
#     not_missing_threshold_percent: minimum 3% values input to have non-missing output value
#     dimensions(sizes): lon(720), lat(360), time(365), nbnds(2)
#     variables(dimensions): float32 lat(lat), float32 lon(lon), float64 time(time), float64 climatology_bounds(time,nbnds), float32 tmax(time,lat,lon), int16 not_missing_count(time,lat,lon)
#     groups:

# %%
tmax.variables.keys()
# Out:
# dict_keys(['lat', 'lon', 'time', 'climatology_bounds', 'tmax', 'not_missing_count'])

# %%
tmax_data=tmax['tmax'][:]

# %%
tmax_lat=tmax['lat'][:].squeeze()
tmax_lon=tmax['lon'][:].squeeze()
tmax_time=tmax.variables['time']
len(tmax_time)
# Out:
# 365

# %%
airtemp=nc.Dataset('./dataset/question2/AIR/air.mon.mean.nc')
airtemp
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     title: NOAA/NCEP GHCN CAMS Monthly Temperature
#     Conventions: CF-1.0
#     Source: http://iridl.ldeo.columbia.edu/SOURCES/.NOAA/.NCEP/.CPC/.GHCN_CAMS/.gridded/.deg0p5/
#     version: 3.01
#     hisotry: Converted to chunked, deflated non-packed NetCDF4 Jun 2014
#     history: created 8/2012 by CAS NOAA/ESRL PSDupdated to include major version change Oct 14, 2015. Antarctica temperature is no longer in the dataset
#     dataset_title: Climate Prediction Center (CPC) Global Land Surface Air Temperature Analysis
#     References: https://www.esrl.noaa.gov/psd/data/gridded/data.ghcncams.html
#     dimensions(sizes): lat(360), lon(720), time(860)
#     variables(dimensions): float32 lat(lat), float32 lon(lon), float64 time(time), float32 air(time,lat,lon)
#     groups:

# %%
airtemp.variables.keys()
# Out:
# dict_keys(['lat', 'lon', 'time', 'air'])

# %%
from netCDF4 import num2date, date2num
airlat=airtemp['lat'][:].squeeze()
airlon=airtemp['lon'][:].squeeze()
airtime=airtemp.variables['time']
len(airtime)
# Out:
# 860

# %%
from netCDF4 import num2date, date2num
airt=[]
for t in range(len(airtime)):
    #print(airtime[t])
    airt.append(int(str(num2date(airtime[t],units=airtime.units))[0:4]))
airyears=list(set(airt))

# %%
airtempdata=airtemp['air'][:]

# %%
air_m_g_mean=[]
for t in range(860):
    air_m_g_mean.append(airtempdata[t].mean())
print(len(air_m_g_mean))
air_m_g_mean=pd.DataFrame(air_m_g_mean)
air_m_g_mean
# Out:
# 860
#               0
# 0    272.450114
# 1    272.564931
# 2    275.622427
# 3    280.789755
# 4    285.786767
# ..          ...
# 855  282.714600
# 856  286.875093
# 857  290.587811
# 858  291.945373
# 859  291.343206
#
# [860 rows x 1 columns]

# %%
temp=[]
for i in range(72):
    temp.append(air_m_g_mean[i:i+12].mean())
air_y_g_mean=pd.DataFrame(temp,index=airyears)
air_y_g_mean
# Out:
#                0
# 1948  281.411703
# 1949  281.400039
# 1950  281.362169
# 1951  281.399858
# 1952  281.398799
# ...          ...
# 2015  281.243825
# 2016  281.241477
# 2017  281.243325
# 2018  281.252829
# 2019  281.310146
#
# [72 rows x 1 columns]

# %%
fig=plt.figure(figsize=(20, 8))
ax=fig.add_subplot(1,1,1)
ax.set_title('global year mean air temp')
#ticks=ax.set_xticks([i for i in range(12)])
#labels = ax.set_xticklabels([y for y in range(1970,2012,5)])
ax.plot(air_y_g_mean)

# %% [markdown]
# ##### 全球温度

# %%
g_m_land_temp=pd.read_csv('./dataset/question2/GlobalLandTemperatures/GlobalTemperatures.csv',encoding='utf-8',engine='python')

# %%
len(g_m_land_temp)
# Out:
# 3156

# %%
land_temp_years=g_m_land_temp['dt']
list(land_temp_years)
temp_years=[]
for i in list(land_temp_years):
    #print(i[0:4])
    temp_years.append(int(i[0:4]))
landtemp_years=set(temp_years)

# %%
temp=[]
for i in range(263):
    temp.append(g_m_land_temp[i:i+12]['LandAverageTemperature'].mean())
g_y_land_temp=pd.DataFrame(temp,index=landtemp_years)
g_y_land_temp
# Out:
#              0
# 1753  8.388083
# 1754  8.349333
# 1755  8.185667
# 1756  8.040083
# 1757  8.318250
# ...        ...
# 2011  8.633083
# 2012  8.482917
# 2013  8.510917
# 2014  8.524250
# 2015  8.672750
#
# [263 rows x 1 columns]

# %%
fig=plt.figure(figsize=(20, 8))
ax=fig.add_subplot(1,1,1)
ax.set_title('global year mean land temp')
#ticks=ax.set_xticks([i for i in range(12)])
#labels = ax.set_xticklabels([y for y in range(1970,2012,5)])
ax.plot(g_y_land_temp)

# %% [markdown]
# ##### 多元线性回归

# %%
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
pd.options.display.max_rows=10

# %%
gtempdf=g_y_land_temp[226:-3].rename(columns={0:'temp'})
gtempdf['key']=gtempdf.index
gtempdf
# Out:
#           temp   key
# 1979  7.709333  1979
# 1980  7.944333  1980
# 1981  8.193500  1981
# 1982  8.052667  1982
# 1983  8.047917  1983
# ...        ...   ...
# 2008  9.456750  2008
# 2009  9.273333  2009
# 2010  8.887833  2010
# 2011  8.633083  2011
# 2012  8.482917  2012
#
# [34 rows x 2 columns]

# %%
co2df=co2_y_g_mean.rename(columns={0:'co2'})
co2df.index
co2years=[]
for i in co2df.index:
    co2years.append(int(i))
co2df['key']=co2years
co2df
# Out:
#               co2   key
# 1979  5228.919312  1979
# 1980  5358.305639  1980
# 1981  5276.944511  1981
# 1982  5365.938797  1982
# 1983  5476.605064  1983
# ...           ...   ...
# 2008  6752.753849  2008
# 2009  6722.120120  2009
# 2010  6989.937205  2010
# 2011  7158.411046  2011
# 2012  7193.681428  2012
#
# [34 rows x 2 columns]

# %%
sst_y_g_mean[125:-7]
sstdf=sst_y_g_mean[125:-7].rename(columns={0:'stt'})
sstdf['key']=sstdf.index
sstdf
# Out:
#             stt   key
# 1979  13.538790  1979
# 1980  13.538469  1980
# 1981  13.547110  1981
# 1982  13.557102  1982
# 1983  13.565944  1983
# ...         ...   ...
# 2008  13.511585  2008
# 2009  13.499620  2009
# 2010  13.483861  2010
# 2011  13.468206  2011
# 2012  13.462554  2012
#
# [34 rows x 2 columns]

# %%
olrdf=olr_y_g_mean.rename(columns={0:'olr'})
olrdf['key']=olrdf.index
olrdf
# Out:
#              olr   key
# 1979  221.895243  1979
# 1980  221.925456  1980
# 1981  222.101196  1981
# 1982  222.215454  1982
# 1983  222.308004  1983
# ...          ...   ...
# 2008  222.413411  2008
# 2009  222.338521  2009
# 2010  222.305969  2010
# 2011  222.162374  2011
# 2012  222.088684  2012
#
# [34 rows x 2 columns]

# %%
datadf=pd.merge(gtempdf,sstdf)
datadf=pd.merge(datadf,olrdf)
datadf=pd.merge(datadf,co2df,on='key')
datadf.reindex=datadf['key']
datadf
# Out:
#         temp   key        stt         olr          co2
# 0   7.709333  1979  13.538790  221.895243  5228.919312
# 1   7.944333  1980  13.538469  221.925456  5358.305639
# 2   8.193500  1981  13.547110  222.101196  5276.944511
# 3   8.052667  1982  13.557102  222.215454  5365.938797
# 4   8.047917  1983  13.565944  222.308004  5476.605064
# ..       ...   ...        ...         ...          ...
# 29  9.456750  2008  13.511585  222.413411  6752.753849
# 30  9.273333  2009  13.499620  222.338521  6722.120120
# 31  8.887833  2010  13.483861  222.305969  6989.937205
# 32  8.633083  2011  13.468206  222.162374  7158.411046
# 33  8.482917  2012  13.462554  222.088684  7193.681428
#
# [34 rows x 5 columns]

# %%
datadf[datadf.isnull()==True].count()
# Out:
# temp    0
# key     0
# stt     0
# olr     0
# co2     0
# dtype: int64

# %%
datadf.boxplot()

# %%
datadf.corr().abs()
# Out:
#           temp       key       stt       olr       co2
# temp  1.000000  0.783569  0.425528  0.252891  0.661010
# key   0.783569  1.000000  0.733972  0.035151  0.954466
# stt   0.425528  0.733972  1.000000  0.517992  0.816323
# olr   0.252891  0.035151  0.517992  1.000000  0.064035
# co2   0.661010  0.954466  0.816323  0.064035  1.000000

# %% [markdown]
# - 相关系数矩阵 r(相关系数) = x和y的协方差/(x的标准差*y的标准差) == cov（x,y）/σx*σy
# - 相关系数0~0.3弱相关0.3~0.6中等程度相关0.6~1强相关

# %%
datadf.corr()
# Out:
#           temp       key       stt       olr       co2
# temp  1.000000  0.783569 -0.425528  0.252891  0.661010
# key   0.783569  1.000000 -0.733972  0.035151  0.954466
# stt  -0.425528 -0.733972  1.000000  0.517992 -0.816323
# olr   0.252891  0.035151  0.517992  1.000000 -0.064035
# co2   0.661010  0.954466 -0.816323 -0.064035  1.000000

# %%
import seaborn as sns

# %%
sns.pairplot(datadf, x_vars=['stt','olr','co2'],y_vars=['temp'],height=7, aspect=0.8,kind = 'reg')
plt.show()
# Out:
# D:\ProgramFiles\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
x_train_temp,x_test_temp,y_train_temp,y_test_temp= train_test_split(datadf[['co2', 'olr','stt']],datadf['temp'],train_size=.80)

# %%
x_train_temp
# Out:
#             co2         olr        stt
# 6   5578.545995  222.597066  13.568577
# 14  5720.968936  222.781006  13.586692
# 24  6268.783335  222.732422  13.528375
# 25  6398.307496  222.745565  13.514428
# 21  6110.327597  222.552877  13.546024
# ..          ...         ...        ...
# 9   5864.928078  222.900513  13.575567
# 29  6752.753849  222.413411  13.511585
# 26  6503.206510  222.693502  13.496926
# 15  5775.576999  222.755005  13.577523
# 33  7193.681428  222.088684  13.462554
#
# [27 rows x 3 columns]

# %%
x_test_temp
# Out:
#             co2         olr        stt
# 8   5773.790327  222.802266  13.565456
# 1   5358.305639  221.925456  13.538469
# 5   5460.355627  222.463562  13.575508
# 28  6593.486842  222.470093  13.513229
# 7   5646.652271  222.738200  13.562146
# 11  5709.883275  222.914347  13.579422
# 22  6100.002223  222.580668  13.538173

# %%
y_train_temp
# Out:
# 6     8.208083
# 14    8.221500
# 24    9.198917
# 25    9.170583
# 21    9.340000
#         ...
# 9     8.483083
# 29    9.456750
# 26    8.772167
# 15    8.230833
# 33    8.482917
# Name: temp, Length: 27, dtype: float64

# %%
y_test_temp
# Out:
# 8     8.491167
# 1     7.944333
# 5     8.161667
# 28    9.280417
# 7     8.477500
# 11    8.625667
# 22    9.379583
# Name: temp, dtype: float64

# %%
model_temp=LinearRegression()
model_temp.fit(x_train_temp,y_train_temp)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
a_temp = model_temp.intercept_
a_temp
# Out:
# -109.63716607421635

# %%
b_temp = model_temp.coef_
np.round(b_temp,3)
# Out:
# array([ 0.   ,  0.691, -2.812])

# %%
x_test_temp
# Out:
#             co2         olr        stt
# 8   5773.790327  222.802266  13.565456
# 1   5358.305639  221.925456  13.538469
# 5   5460.355627  222.463562  13.575508
# 28  6593.486842  222.470093  13.513229
# 7   5646.652271  222.738200  13.562146
# 11  5709.883275  222.914347  13.579422
# 22  6100.002223  222.580668  13.538173

# %%
model_temp.predict(x_test_temp)
# Out:
# array([8.65962364, 7.95301901, 8.264129  , 8.92508541, 8.57064715,
#        8.67067339, 8.72174897])

# %% [markdown]
# $$ Y = 0.000522 * CO2 + 0.550881 * OLR - 0.983653 * STT -103.811113 $$

# %% [markdown]
# #### 检验与预测

# %%
score_temp=model_temp.score(x_test_temp,y_test_temp)
score_temp
# Out:
# 0.6454247450953585

# %%
y_pred = model_temp.predict(x_test_temp)
y_pred
# Out:
# array([8.6922559 , 8.64792263, 7.95046714, 8.948182  , 8.69266911,
#        8.6676084 , 8.23428689])

# %%
np.array(y_test_temp)
# Out:
# array([8.6205    , 8.68516667, 7.94433333, 9.27333333, 8.25658333,
#        8.23083333, 8.04791667])

# %%
fig=plt.figure(figsize=(20, 10))
ax=fig.add_subplot(1,1,1)
ax.plot(y_pred,label='y_predict')
ax.plot(np.array(y_test_temp),label='y_test_temp')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.legend(fontsize=20)
ax.set_title('Predict and Test',fontsize=20)
ax.legend(fontsize=20)

# %% [markdown]
# ##### 对于温室气体的影响选择

# %% [markdown]
# #### 预测未来25年的气候变迁

# %%
co2df
# Out:
#               co2   key
# 1979  5228.919312  1979
# 1980  5358.305639  1980
# 1981  5276.944511  1981
# 1982  5365.938797  1982
# 1983  5476.605064  1983
# ...           ...   ...
# 2008  6752.753849  2008
# 2009  6722.120120  2009
# 2010  6989.937205  2010
# 2011  7158.411046  2011
# 2012  7193.681428  2012
#
# [34 rows x 2 columns]

# %%
x_train_co2,x_test_co2,y_train_co2,y_test_co2 = train_test_split(co2df['key'],co2df['co2'],train_size=.8)

# %% [markdown]
# x_train_co2.values

# %%
fig = plt.figure(figsize=[20,10])
ax = fig.add_subplot(1, 1, 1)
ax.scatter(x_test_co2, y_test_co2, color="red", label="test data")
ax.scatter(x_train_co2, y_train_co2, color="blue", label="train data")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.legend(fontsize=20)
ax.set_title('CO2 Train Data and Test Data',fontsize=20)
# Out:
# Text(0.5,1,'CO2 Train Data and Test Data')

# %%
model_co2 = LinearRegression()
model_co2.fit(x_train_co2.values.reshape(-1,1),y_train_co2.values.reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
a_co2  = model_co2.intercept_
b_co2 = model_co2.coef_
a_co2
# Out:
# array([-95835.94011663])

# %% [markdown]
# b_co2

# %%
co2_years=co2df['key']
co2_years.values
# Out:
# array([1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012], dtype=int64)

# %%
co2_demoo= model_co2.predict(co2_years.values.reshape(-1,1))
co2_demoo=pd.DataFrame(co2_demoo,index=co2_years)
co2_demoo
# Out:
#                 0
# key
# 1979  5210.412583
# 1980  5261.471882
# 1981  5312.531181
# 1982  5363.590480
# 1983  5414.649779
# ...           ...
# 2008  6691.132254
# 2009  6742.191553
# 2010  6793.250852
# 2011  6844.310151
# 2012  6895.369450
#
# [34 rows x 1 columns]

# %%
fig = plt.figure(figsize=[20,10])
ax = fig.add_subplot(1, 1, 1)
ax.scatter(x_test_co2, y_test_co2,label="test data")
ax.scatter(x_train_co2, y_train_co2, label="train data")
ax.plot(co2_demoo,color='green',label='regression')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.legend(fontsize=20)
ax.set_title('CO2 Train Data and Test Data',fontsize=20)
# Out:
# Text(0.5,1,'CO2 Train Data and Test Data')

# %% [markdown]
# $$ CO_{2}=49.24583917 * Years -99564.75062088$$

# %%
x_predict=[i for i in range(2019,2046)]
x_predict=pd.DataFrame(x_predict)
list(x_predict[0])
# Out:
# [2019,
#  2020,
#  2021,
#  2022,
#  2023,
#  2024,
#  2025,
#  2026,
#  2027,
#  2028,
#  2029,
#  2030,
#  2031,
#  2032,
#  2033,
#  2034,
#  2035,
#  2036,
#  2037,
#  2038,
#  2039,
#  2040,
#  2041,
#  2042,
#  2043,
#  2044,
#  2045]

# %%
co2_pred = model_co2.predict(x_predict)
co2_pred=pd.DataFrame(co2_pred)
co2_pred
# Out:
#               0
# 0   7252.784543
# 1   7303.843842
# 2   7354.903141
# 3   7405.962440
# 4   7457.021738
# ..          ...
# 22  8376.089120
# 23  8427.148419
# 24  8478.207718
# 25  8529.267017
# 26  8580.326316
#
# [27 rows x 1 columns]

# %%
fig = plt.figure(figsize=[20,10])
ax = fig.add_subplot(1, 1, 1)
ax.plot(co2_pred,color="red", label="co2_pred")
plt.xticks([y for y in range(27)],fontsize=14)
plt.yticks(fontsize=20)
labels=ax.set_xticklabels(list(x_predict[0]))
ax.legend(fontsize=20)
ax.set_title('CO2 Predict 2019-2045',fontsize=20)
# Out:
# Text(0.5,1,'CO2 Predict 2019-2045')

# %%
score_co2=model_co2.score(x_test_co2.values.reshape(-1,1),y_test_co2)
score_co2
# Out:
# 0.8994276106141951

# %% [markdown]
# ###### 预测OLR

# %%
olrdf
# Out:
#              olr   key
# 1979  221.895243  1979
# 1980  221.925456  1980
# 1981  222.101196  1981
# 1982  222.215454  1982
# 1983  222.308004  1983
# ...          ...   ...
# 2008  222.413411  2008
# 2009  222.338521  2009
# 2010  222.305969  2010
# 2011  222.162374  2011
# 2012  222.088684  2012
#
# [34 rows x 2 columns]

# %%
x_train_olr,x_test_olr,y_train_olr,y_test_olr = train_test_split(olrdf['key'],olrdf['olr'],train_size=.8)

# %%
fig = plt.figure(figsize=[20,10])
ax = fig.add_subplot(1, 1, 1)
ax.scatter(x_test_olr, y_test_olr, color="red", label="test data")
ax.scatter(x_train_olr, y_train_olr, color="blue", label="train data")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.legend(fontsize=20)
ax.set_title('OLR Train Data and Test Data',fontsize=20)
# Out:
# Text(0.5,1,'OLR Train Data and Test Data')

# %%
model_olr = LinearRegression()
model_olr.fit(x_train_olr.values.reshape(-1,1),y_train_olr.values.reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
a_olr  = model_olr.intercept_
b_olr = model_olr.coef_
a_olr
# Out:
# array([213.03213421])

# %%
b_olr
# Out:
# array([[0.00476503]])

# %%
olr_years=co2df['key']
olr_years.values
# Out:
# array([1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012], dtype=int64)

# %%
olr_demoo= model_olr.predict(olr_years.values.reshape(-1,1))
olr_demoo=pd.DataFrame(olr_demoo,index=olr_years.values)
olr_demoo
# Out:
#                0
# 1979  222.462121
# 1980  222.466886
# 1981  222.471651
# 1982  222.476416
# 1983  222.481181
# ...          ...
# 2008  222.600307
# 2009  222.605072
# 2010  222.609837
# 2011  222.614602
# 2012  222.619367
#
# [34 rows x 1 columns]

# %%
fig = plt.figure(figsize=[20,10])
ax = fig.add_subplot(1, 1, 1)
ax.scatter(x_test_olr, y_test_olr,label="test data")
ax.scatter(x_train_olr, y_train_olr,label="train data")
ax.plot(olr_demoo,color='green',label='regression')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.legend(fontsize=20)
ax.set_title('OLR Train Data and Test Data',fontsize=20)
# Out:
# Text(0.5,1,'OLR Train Data and Test Data')

# %% [markdown]
# $$OLR = -0.00202847 * Years +226.58083589$$

# %%
score_olr=model_olr.score(x_test_olr.values.reshape(-1,1),y_test_olr)
score_olr
# Out:
# -0.2998794918680996

# %%
x_predict
# Out:
#        0
# 0   2019
# 1   2020
# 2   2021
# 3   2022
# 4   2023
# ..   ...
# 22  2041
# 23  2042
# 24  2043
# 25  2044
# 26  2045
#
# [27 rows x 1 columns]

# %%
OLR_pred = model_olr.predict(x_predict)
OLR_pred=pd.DataFrame(OLR_pred)
OLR_pred
# Out:
#              0
# 0   222.652722
# 1   222.657487
# 2   222.662252
# 3   222.667017
# 4   222.671782
# ..         ...
# 22  222.757553
# 23  222.762318
# 24  222.767083
# 25  222.771848
# 26  222.776613
#
# [27 rows x 1 columns]

# %%
fig = plt.figure(figsize=[20,10])
ax = fig.add_subplot(1, 1, 1)
ax.plot(OLR_pred,color="red", label="OLR_pred")
plt.xticks([y for y in range(27)],fontsize=14)
plt.yticks(fontsize=20)
labels=ax.set_xticklabels(list(x_predict[0]))
ax.legend(fontsize=20)
ax.set_title('OLR Predict 2019-2045',fontsize=20)
# Out:
# Text(0.5,1,'OLR Predict 2019-2045')

# %% [markdown]
# #### 预测SST

# %%
sstdf
# Out:
#             stt   key
# 1979  13.538790  1979
# 1980  13.538469  1980
# 1981  13.547110  1981
# 1982  13.557102  1982
# 1983  13.565944  1983
# ...         ...   ...
# 2008  13.511585  2008
# 2009  13.499620  2009
# 2010  13.483861  2010
# 2011  13.468206  2011
# 2012  13.462554  2012
#
# [34 rows x 2 columns]

# %%
x_train_sst,x_test_sst,y_train_sst,y_test_sst = train_test_split(sstdf['key'],sstdf['stt'],train_size=.8)

# %%
fig = plt.figure(figsize=[20,10])
ax = fig.add_subplot(1, 1, 1)
ax.scatter(x_test_sst, y_test_sst, color="red", label="test data")
ax.scatter(x_train_sst, y_train_sst, color="blue", label="train data")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.legend(fontsize=20)
ax.set_title('SST Train Data and Test Data',fontsize=20)
# Out:
# Text(0.5,1,'SST Train Data and Test Data')

# %%
model_sst = LinearRegression()
model_sst.fit(x_train_sst.values.reshape(-1,1),y_train_sst.values.reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
a_sst  = model_sst.intercept_
b_sst = model_sst.coef_
a_sst
# Out:
# array([18.04981654])

# %%
b_sst
# Out:
# array([[-0.00225692]])

# %%
sst_years=sstdf['key']
sst_years.values
# Out:
# array([1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012], dtype=int64)

# %%
sst_demoo= model_sst.predict(sst_years.values.reshape(-1,1))
sst_demoo=pd.DataFrame(sst_demoo,index=sst_years.values)
sst_demoo
# Out:
#               0
# 1979  13.583364
# 1980  13.581107
# 1981  13.578850
# 1982  13.576594
# 1983  13.574337
# ...         ...
# 2008  13.517914
# 2009  13.515657
# 2010  13.513400
# 2011  13.511143
# 2012  13.508886
#
# [34 rows x 1 columns]

# %%
fig = plt.figure(figsize=[20,10])
ax = fig.add_subplot(1, 1, 1)
ax.scatter(x_test_sst, y_test_sst,label="test data")
ax.scatter(x_train_sst, y_train_sst,label="train data")
ax.plot(sst_demoo,color='green',label='regression')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.legend(fontsize=20)
ax.set_title('SST Train Data and Test Data',fontsize=20)
# Out:
# Text(0.5,1,'SST Train Data and Test Data')

# %% [markdown]
# $$SST=-0.00238692*Years+18.30723597$$

# %%
score_sst=model_sst.score(x_test_sst.values.reshape(-1,1),y_test_sst)
score_sst
# Out:
# 0.663139169586419

# %%
sst_pred = model_sst.predict(x_predict)
sst_pred=pd.DataFrame(sst_pred)
sst_pred=sst_pred[0].sort_values(ascending=True)
sst_pred=pd.DataFrame(sst_pred)
sst_pred=list(sst_pred[0])
sst_pred=pd.DataFrame(sst_pred)
sst_pred
# Out:
#             0
# 0   13.434407
# 1   13.436664
# 2   13.438921
# 3   13.441178
# 4   13.443435
# ..        ...
# 22  13.484060
# 23  13.486317
# 24  13.488573
# 25  13.490830
# 26  13.493087
#
# [27 rows x 1 columns]

# %%
fig = plt.figure(figsize=[20,10])
ax = fig.add_subplot(1, 1, 1)
ax.plot(sst_pred,color="red", label="SST_pred")
plt.xticks([y for y in range(27)],fontsize=14)
plt.yticks(fontsize=20)
labels=ax.set_xticklabels(list(x_predict[0]))
ax.legend(fontsize=20)
ax.set_title('SST Predict 2019-2045',fontsize=20)
# Out:
# Text(0.5,1,'SST Predict 2019-2045')

# %% [markdown]
# #### 最终结果

# %%
co2_pred['key']=x_predict
co2_pred=co2_pred.rename(columns={0:'CO2p'})

# %%
OLR_pred['key']=x_predict
OLR_pred=OLR_pred.rename(columns={0:'OLRp'})

# %%
sst_pred['key']=x_predict
sst_pred=sst_pred.rename(columns={0:'SSTp'})

# %%
predictfact=pd.merge(co2_pred,OLR_pred,on='key')

# %%
predictfact=pd.merge(predictfact,sst_pred)
del predictfact['key']

# %%
result = model_temp.predict(predictfact)

# %%
result
# Out:
# array([ 9.41548201,  9.44762028,  9.47975856,  9.51189683,  9.54403511,
#         9.57617338,  9.60831165,  9.64044993,  9.6725882 ,  9.70472647,
#         9.73686475,  9.76900302,  9.8011413 ,  9.83327957,  9.86541784,
#         9.89755612,  9.92969439,  9.96183266,  9.99397094, 10.02610921,
#        10.05824749, 10.09038576, 10.12252403, 10.15466231, 10.18680058,
#        10.21893886, 10.25107713])

# %%
result=[9.41548201,9.70472647, 9.51189683,9.44762028,9.54403511,9.57617338,9.6725882,9.47975856,9.64044993, 9.83327957,  9.86541784, 9.73686475,  9.76900302,  9.8011413 ,9.60831165,10.02610921,9.89755612, 10.09038576,10.05824749 ,10.18680058,9.92969439, 10.12252403, 9.92969439, 9.99397094, 9.96183266, 10.25107713,10.21893886]

# %%
fig=plt.figure(figsize=(20, 10))
ax=fig.add_subplot(1,1,1)
ax.plot(x_predict,result,label='predict_global_temp')
#ax.imshow(result.stack(),cmap='Blues',alpha = 0.5, aspect = 'auto')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#ax.legend(fontsize=20)
ax.set_title('Predict Gobal Land Temp 2019-2045',fontsize=20)
ax.legend(fontsize=20)
